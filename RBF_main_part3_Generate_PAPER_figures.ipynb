# %%
import numpy as np
import matplotlib.pyplot as plt

import matplotlib

matplotlib.use("pgf")
matplotlib.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'font.size' : 8,
    'text.usetex': True,
    'pgf.rcfonts': False,
})
#matplotlib.rcParams.update(matplotlib.rcParamsDefault)
#matplotlib.rcParams.update({'font.size': 12})
#matplotlib.rcdefaults()


# Load the .npz file
data = np.load('RBF_plot_data.npz')

# Extract and assign each array to its original variable name
kmax = data['kmax']
seed = data['seed']
sigmax = data['sigmax']

Ps = data['Ps']
Qs = data['Qs']

P = data['P']
Q = data['Q']
sigma = data['sigma']
d = data['d']

Mss = data['Mss']
Mns = data['Mns']
Mk0s = data['Mk0s']
Mk1s = data['Mk1s']

Mss_s = data['Mss_s']
Mns_s = data['Mns_s']
Mk0s_s = data['Mk0s_s']
Mk1s_s = data['Mk1s_s']

Mss2_s = data['Mss2_s']
Mns2_s = data['Mns2_s']
Mk0s2_s = data['Mk0s2_s']
Mk1s2_s = data['Mk1s2_s']

Mts = data['Mts']

# Optional: Close the .npz file
data.close()

# %%
#fig.set_size_inches(w=6.75133/1.5, h=5)


#fig.tight_layout()

#plt.savefig('RBF1.pdf', bbox_inches='tight')

# %%
fig,ax=plt.subplots(2,5,figsize=(20,10))

ms=4
lw=0.5
lwgt=1
mew=0.7

ylog=True
ls='--'
eb_alpha=0.5

alphaGT=0.5
cGT='b'
#fig,ax=plt.subplots(2,2,figsize=(6,6))
#ax.plot(Ps,gims,c='k',label='theory')


xoi=np.arange(kmax-1)+2
qoi=Mss
colorv='r'
zo=10
yval=np.nanmedian(qoi,axis=1)
lower_error=np.nanquantile(qoi,axis=1,q=0.25)
upper_error=np.nanquantile(qoi,axis=1,q=0.75)
asymmetric_error = [yval-lower_error, upper_error-yval]
ax[0][0].errorbar(xoi, yval, yerr=asymmetric_error,c=colorv,marker='',ls='',alpha=eb_alpha,lw=lw,zorder=zo)#, fmt='o')
yval=np.nanmean(qoi,axis=1)
#ax[0][0].plot(xoi, yval,c=colorv,marker='x',ls=ls,alpha=0.75,ms=10,lw=lw,label=r'Ours',zorder=zo*100)#, fmt='o')
ax[0][0].plot(xoi, yval,c=colorv,marker='x',fillstyle='none',ls='--',alpha=0.75,ms=ms,lw=lw,label=r'Ours',zorder=zo*100,markeredgewidth=mew)#, fmt='o')


qoi=Mns
colorv='k'
zo=5
yval=np.nanmedian(qoi,axis=1)
lower_error=np.nanquantile(qoi,axis=1,q=0.25)
upper_error=np.nanquantile(qoi,axis=1,q=0.75)
asymmetric_error = [yval-lower_error, upper_error-yval]
ax[0][0].errorbar(xoi, yval, yerr=asymmetric_error,c=colorv,marker='',ls='',alpha=eb_alpha,lw=lw,zorder=zo)#, fmt='o')
yval=np.nanmean(qoi,axis=1)
#ax[0][0].plot(xoi, yval,c=colorv,marker='x',ls=ls,alpha=0.75,ms=10,lw=lw,label=r'Naive',zorder=zo*100)#, fmt='o')
ax[0][0].plot(xoi, yval,c=colorv,marker='o',fillstyle='none',ls='--',alpha=0.75,ms=ms,lw=lw,label=r'Naive',zorder=zo*100,markeredgewidth=mew)#, fmt='o')


qoi=Mk0s
colorv='g'
zo=1
yval=np.nanmedian(qoi,axis=1)
lower_error=np.nanquantile(qoi,axis=1,q=0.25)
upper_error=np.nanquantile(qoi,axis=1,q=0.75)
asymmetric_error = [yval-lower_error, upper_error-yval]
ax[0][0].errorbar(xoi, yval, yerr=asymmetric_error,c=colorv,marker='',ls='',alpha=eb_alpha,lw=lw,zorder=zo)#, fmt='o')
yval=np.nanmean(qoi,axis=1)
#ax[0][0].plot(xoi, yval,c=colorv,marker='+',ls=ls,alpha=0.75,ms=10,lw=lw,label=r'KV row',zorder=zo*100)#, fmt='o')
ax[0][0].plot(xoi, yval,c=colorv,marker='>',fillstyle='none',ls='--',alpha=0.75,ms=ms,lw=lw,label=r'KV row',zorder=zo*100,markeredgewidth=mew)#, fmt='o')



qoi=Mk1s
colorv='g'
zo=1
yval=np.nanmedian(qoi,axis=1)
lower_error=np.nanquantile(qoi,axis=1,q=0.25)
upper_error=np.nanquantile(qoi,axis=1,q=0.75)
asymmetric_error = [yval-lower_error, upper_error-yval]
ax[0][0].errorbar(xoi, yval, yerr=asymmetric_error,c=colorv,marker='',ls='',alpha=eb_alpha,lw=lw,zorder=zo)#, fmt='o')
yval=np.nanmean(qoi,axis=1)
#ax[0][0].plot(xoi, yval,c=colorv,marker='x',ls=ls,alpha=0.75,ms=10,lw=lw,label=r'KV col',zorder=zo*100)#, fmt='o')
ax[0][0].plot(xoi, yval,c=colorv,marker='<',fillstyle='none',ls='--',alpha=0.75,ms=ms,lw=lw,label=r'KV col',zorder=zo*100,markeredgewidth=mew)#, fmt='o')

zo=-1
ax[0][0].plot(xoi,np.array(Mts),c=cGT,lw=lwgt,alpha=alphaGT,label='GT',zorder=zo)

#ax.set_xscale('log')
ax[0][0].set_xlabel('n')
ax[0][0].set_title(r'$\hat{m}(n)$')
#ax.set_title('N={}, Q={}'.format(N,Q),fontsize=11)


fig.legend(loc='center left', bbox_to_anchor=(1, 0.5),fontsize=8)
#.legend(fontsize=10)






gt=np.array(Mts)

#fig,ax=plt.subplots(1,3,figsize=(12,4))
#ax.plot(Ps,gims,c='k',label='theory')

xoi=np.arange(kmax-1)+2
qoi=Mss
yval=np.nanmean(np.square(gt[:,None]-qoi),axis=1)
colorv='r'
zo=10
#ax[0][1].plot(xoi, yval,c=colorv,marker='x',ls=ls,alpha=0.75,ms=10,lw=lw,label=r'Ours',zorder=zo*100)#, fmt='o')
ax[0][1].plot(xoi, yval,c=colorv,marker='x',fillstyle='none',ls='--',alpha=0.75,ms=ms,lw=lw,label=r'Ours',zorder=zo*100,markeredgewidth=mew)#, fmt='o')

xoi=np.arange(kmax-1)+2
qoi=Mns
yval=np.nanmean(np.square(gt[:,None]-qoi),axis=1)
colorv='k'
zo=5
#ax[0][1].plot(xoi, yval,c=colorv,marker='x',ls=ls,alpha=0.75,ms=10,lw=lw,label=r'Naive',zorder=zo*100)#, fmt='o')
ax[0][1].plot(xoi, yval,c=colorv,marker='o',fillstyle='none',ls='--',alpha=0.75,ms=ms,lw=lw,label=r'Naive',zorder=zo*100,markeredgewidth=mew)#, fmt='o')

xoi=np.arange(kmax-1)+2
qoi=Mk0s
yval=np.nanmean(np.square(gt[:,None]-qoi),axis=1)
colorv='g'
zo=1
#ax[0][1].plot(xoi, yval,c=colorv,marker='+',ls=ls,alpha=0.75,ms=10,lw=lw,label=r'Kong row',zorder=zo*100)#, fmt='o')
ax[0][1].plot(xoi, yval,c=colorv,marker='>',fillstyle='none',ls='--',alpha=0.75,ms=ms,lw=lw,label=r'KV row',zorder=zo*100,markeredgewidth=mew)#, fmt='o')

xoi=np.arange(kmax-1)+2
qoi=Mk1s
yval=np.nanmean(np.square(gt[:,None]-qoi),axis=1)
colorv='g'
zo=1
#ax[0][1].plot(xoi, yval,c=colorv,marker='x',ls=ls,alpha=0.75,ms=10,lw=lw,label=r'Kong col',zorder=zo*100)#, fmt='o')
ax[0][1].plot(xoi, yval,c=colorv,marker='<',fillstyle='none',ls='--',alpha=0.75,ms=ms,lw=lw,label=r'KV col',zorder=zo*100,markeredgewidth=mew)#, fmt='o')



#ax.set_xscale('log')
ax[0][1].set_xlabel('n')
ax[0][1].set_title('MSE')
#ax[1].legend(fontsize=11)
#ax.set_title('N={}, Q={}'.format(N,Q),fontsize=11)


if ylog:
    ax[0][0].set_yscale('log')
    ax[0][1].set_yscale('log')

    
    

Mss_p=np.power(Mss,1/np.arange(2,kmax+1)[:,None])
Mns_p=np.power(Mns,1/np.arange(2,kmax+1)[:,None])
Mk0s_p=np.power(Mk0s,1/np.arange(2,kmax+1)[:,None])
Mk1s_p=np.power(Mk1s,1/np.arange(2,kmax+1)[:,None])
Mts_p=np.power(Mts,1/np.arange(2,kmax+1))

ylog=True
ls='--'
eb_alpha=0.5

#fig,ax=plt.subplots(1,2,figsize=(12,3))
#ax.plot(Ps,gims,c='k',label='theory')

xoi=np.arange(kmax-1)+2
qoi=Mss_p
colorv='r'
zo=10
yval=np.nanmedian(qoi,axis=1)
lower_error=np.nanquantile(qoi,axis=1,q=0.25)
upper_error=np.nanquantile(qoi,axis=1,q=0.75)
asymmetric_error = [yval-lower_error, upper_error-yval]
ax[1][0].errorbar(xoi, yval, yerr=asymmetric_error,c=colorv,marker='',ls='',alpha=eb_alpha,lw=lw,zorder=zo)#, fmt='o')
yval=np.nanmean(qoi,axis=1)
#ax[1][0].plot(xoi, yval,c=colorv,marker='x',ls=ls,alpha=0.75,ms=10,lw=lw,label=r'Ours',zorder=zo*100)#, fmt='o')
ax[1][0].plot(xoi, yval,c=colorv,marker='x',fillstyle='none',ls='--',alpha=0.75,ms=ms,lw=lw,label=r'Ours',zorder=zo*100,markeredgewidth=mew)#, fmt='o')


qoi=Mns_p
colorv='k'
zo=5
yval=np.nanmedian(qoi,axis=1)
lower_error=np.nanquantile(qoi,axis=1,q=0.25)
upper_error=np.nanquantile(qoi,axis=1,q=0.75)
asymmetric_error = [yval-lower_error, upper_error-yval]
ax[1][0].errorbar(xoi, yval, yerr=asymmetric_error,c=colorv,marker='',ls='',alpha=eb_alpha,lw=lw,zorder=zo)#, fmt='o')
yval=np.nanmean(qoi,axis=1)
#ax[1][0].plot(xoi, yval,c=colorv,marker='x',ls=ls,alpha=0.75,ms=10,lw=lw,label=r'Naive',zorder=zo*100)#, fmt='o')
ax[1][0].plot(xoi, yval,c=colorv,marker='o',fillstyle='none',ls='--',alpha=0.75,ms=ms,lw=lw,label=r'Naive',zorder=zo*100,markeredgewidth=mew)#, fmt='o')


qoi=Mk0s_p
colorv='g'
zo=1
yval=np.nanmedian(qoi,axis=1)
lower_error=np.nanquantile(qoi,axis=1,q=0.25)
upper_error=np.nanquantile(qoi,axis=1,q=0.75)
asymmetric_error = [yval-lower_error, upper_error-yval]
ax[1][0].errorbar(xoi, yval, yerr=asymmetric_error,c=colorv,marker='',ls='',alpha=eb_alpha,lw=lw,zorder=zo)#, fmt='o')
yval=np.nanmean(qoi,axis=1)
#ax[1][0].plot(xoi, yval,c=colorv,marker='+',ls=ls,alpha=0.75,ms=10,lw=lw,label=r'KV row',zorder=zo*100)#, fmt='o')
ax[1][0].plot(xoi, yval,c=colorv,marker='>',fillstyle='none',ls='--',alpha=0.75,ms=ms,lw=lw,label=r'KV row',zorder=zo*100,markeredgewidth=mew)#, fmt='o')



qoi=Mk1s_p
colorv='g'
zo=1
yval=np.nanmedian(qoi,axis=1)
lower_error=np.nanquantile(qoi,axis=1,q=0.25)
upper_error=np.nanquantile(qoi,axis=1,q=0.75)
asymmetric_error = [yval-lower_error, upper_error-yval]
ax[1][0].errorbar(xoi, yval, yerr=asymmetric_error,c=colorv,marker='',ls='',alpha=eb_alpha,lw=lw,zorder=zo)#, fmt='o')
yval=np.nanmean(qoi,axis=1)
#ax[1][0].plot(xoi, yval,c=colorv,marker='x',ls=ls,alpha=0.75,ms=10,lw=lw,label=r'KV col',zorder=zo*100)#, fmt='o')
ax[1][0].plot(xoi, yval,c=colorv,marker='<',fillstyle='none',ls='--',alpha=0.75,ms=ms,lw=lw,label=r'KV col',zorder=zo*100,markeredgewidth=mew)#, fmt='o')

zo=-1
ax[1][0].plot(xoi,np.array(Mts_p),c=cGT,lw=lwgt,alpha=alphaGT,label='GT',zorder=zo)

#ax.set_xscale('log')
ax[1][0].set_xlabel('n')
ax[1][0].set_title(r'$\hat{m}(n)^{1/n}$')
#ax.set_title('N={}, Q={}'.format(N,Q),fontsize=11)



gt=np.array(Mts_p)

#fig,ax=plt.subplots(1,3,figsize=(12,4))
#ax.plot(Ps,gims,c='k',label='theory')

xoi=np.arange(kmax-1)+2
qoi=Mss_p
yval=np.nanmean(np.square(gt[:,None]-qoi),axis=1)
colorv='r'
zo=10
#ax[1][1].plot(xoi, yval,c=colorv,marker='x',ls=ls,alpha=0.75,ms=10,lw=lw,label=r'Ours',zorder=zo*100)#, fmt='o')
ax[1][1].plot(xoi, yval,c=colorv,marker='x',fillstyle='none',ls='--',alpha=0.75,ms=ms,lw=lw,label=r'Ours',zorder=zo*100,markeredgewidth=mew)#, fmt='o')

xoi=np.arange(kmax-1)+2
qoi=Mns_p
yval=np.nanmean(np.square(gt[:,None]-qoi),axis=1)
colorv='k'
zo=5
#ax[1][1].plot(xoi, yval,c=colorv,marker='x',ls=ls,alpha=0.75,ms=10,lw=lw,label=r'Naive',zorder=zo*100)#, fmt='o')
ax[1][1].plot(xoi, yval,c=colorv,marker='o',fillstyle='none',ls='--',alpha=0.75,ms=ms,lw=lw,label=r'Naive',zorder=zo*100,markeredgewidth=mew)#, fmt='o')

xoi=np.arange(kmax-1)+2
qoi=Mk0s_p
yval=np.nanmean(np.square(gt[:,None]-qoi),axis=1)
colorv='g'
zo=1
#ax[1][1].plot(xoi, yval,c=colorv,marker='+',ls=ls,alpha=0.75,ms=10,lw=lw,label=r'Kong row',zorder=zo*100)#, fmt='o')
ax[1][1].plot(xoi, yval,c=colorv,marker='>',fillstyle='none',ls='--',alpha=0.75,ms=ms,lw=lw,label=r'KV row',zorder=zo*100,markeredgewidth=mew)#, fmt='o')

xoi=np.arange(kmax-1)+2
qoi=Mk1s_p
yval=np.nanmean(np.square(gt[:,None]-qoi),axis=1)
colorv='g'
zo=1
#ax[1][1].plot(xoi, yval,c=colorv,marker='x',ls=ls,alpha=0.75,ms=10,lw=lw,label=r'Kong col',zorder=zo*100)#, fmt='o')
ax[1][1].plot(xoi, yval,c=colorv,marker='<',fillstyle='none',ls='--',alpha=0.75,ms=ms,lw=lw,label=r'KV col',zorder=zo*100,markeredgewidth=mew)#, fmt='o')



#ax.set_xscale('log')
ax[1][1].set_xlabel('n')
ax[1][1].set_title('MSE')
#ax[1].legend(fontsize=11)
#ax.set_title('N={}, Q={}'.format(N,Q),fontsize=11)



if ylog:
    #ax[0].set_yscale('log')
    ax[1][1].set_yscale('log')
    #ax[1][2].set_yscale('log')
    #ax[1][3].set_yscale('log')


#ax[1][0].legend(fontsize=10).set_zorder(-100000)
    
    
#############################################################################################


#for i in range(np.shape(Mss_s)[1]):
for i in range(3):
    #ax.plot(Qs,Mss_s[:,i,:])
    xoi=Qs
    
    qoi=Mss_s[:,i,:]#-Mts[i]
    colorv='r'
    zo=10
    yval=np.nanmedian(qoi,axis=1)
    lower_error=np.nanquantile(qoi,axis=1,q=0.25)
    upper_error=np.nanquantile(qoi,axis=1,q=0.75)
    asymmetric_error = [yval-lower_error, upper_error-yval]
    ax[0][i+2].errorbar(xoi, yval, yerr=asymmetric_error,c=colorv,marker='',ls='',alpha=0.5,lw=lw,zorder=zo)#, fmt='o')
    yval=np.nanmean(qoi,axis=1)
    ax[0][i+2].plot(xoi, yval,c=colorv,marker='x',fillstyle='none',ls='--',alpha=0.75,ms=ms,lw=lw,label=r'Ours',zorder=zo*100,markeredgewidth=mew)#, fmt='o')

    
    qoi=Mns_s[:,i,:]#-Mts[i]
    colorv='k'
    zo=10
    yval=np.nanmedian(qoi,axis=1)
    lower_error=np.nanquantile(qoi,axis=1,q=0.25)
    upper_error=np.nanquantile(qoi,axis=1,q=0.75)
    asymmetric_error = [yval-lower_error, upper_error-yval]
    ax[0][i+2].errorbar(xoi, yval, yerr=asymmetric_error,c=colorv,marker='',ls='',alpha=0.5,lw=lw,zorder=zo)#, fmt='o')
    yval=np.nanmean(qoi,axis=1)
    ax[0][i+2].plot(xoi, yval,c=colorv,marker='o',fillstyle='none',ls='--',alpha=0.75,ms=ms,lw=lw,label=r'Naive',zorder=zo*100,markeredgewidth=mew)#, fmt='o')

    qoi=Mk0s_s[:,i,:]#-Mts[i]
    colorv='g'
    zo=10
    yval=np.nanmedian(qoi,axis=1)
    lower_error=np.nanquantile(qoi,axis=1,q=0.25)
    upper_error=np.nanquantile(qoi,axis=1,q=0.75)
    asymmetric_error = [yval-lower_error, upper_error-yval]
    ax[0][i+2].errorbar(xoi, yval, yerr=asymmetric_error,c=colorv,marker='',ls='',alpha=0.5,lw=lw,zorder=zo)#, fmt='o')
    yval=np.nanmean(qoi,axis=1)
    ax[0][i+2].plot(xoi, yval,c=colorv,marker='>',fillstyle='none',ls='--',alpha=0.75,ms=ms,lw=lw,label=r'KV row',zorder=zo*100,markeredgewidth=mew)#, fmt='o')

    qoi=Mk1s_s[:,i,:]#-Mts[i]
    colorv='g'
    zo=10
    yval=np.nanmedian(qoi,axis=1)
    lower_error=np.nanquantile(qoi,axis=1,q=0.25)
    upper_error=np.nanquantile(qoi,axis=1,q=0.75)
    asymmetric_error = [yval-lower_error, upper_error-yval]
    ax[0][i+2].errorbar(xoi, yval, yerr=asymmetric_error,c=colorv,marker='',ls='',alpha=0.5,lw=lw,zorder=zo)#, fmt='o')
    yval=np.nanmean(qoi,axis=1)
    ax[0][i+2].plot(xoi, yval,c=colorv,marker='<',fillstyle='none',ls='--',alpha=0.75,ms=ms,lw=lw,label=r'KV col',zorder=zo*100,markeredgewidth=mew)#, fmt='o')
  
    
    ax[0][i+2].hlines(Mts[i],np.min(Qs),np.max(Qs),color=cGT,alpha=alphaGT,lw=lwgt,label='GT')
    ax[0][i+2].set_xscale('log')
    ax[0][i+2].set_yscale('log')
    ax[0][i+2].set_xlabel('Q')
    ax[0][i+2].set_title(r'$\hat{{m}}({})$'.format(i+2))
    
    ###############################################################
    
    xoi=Ps
    
    qoi=Mss2_s[:,i,:]#-Mts[i]
    colorv='r'
    zo=10
    yval=np.nanmedian(qoi,axis=1)
    lower_error=np.nanquantile(qoi,axis=1,q=0.25)
    upper_error=np.nanquantile(qoi,axis=1,q=0.75)
    asymmetric_error = [yval-lower_error, upper_error-yval]
    ax[1][i+2].errorbar(xoi, yval, yerr=asymmetric_error,c=colorv,marker='',ls='',alpha=0.5,lw=lw,zorder=zo)#, fmt='o')
    yval=np.nanmean(qoi,axis=1)
    ax[1][i+2].plot(xoi, yval,c=colorv,marker='x',fillstyle='none',ls='--',alpha=0.75,ms=ms,lw=lw,label=r'Ours',zorder=zo*100,markeredgewidth=mew)#, fmt='o')

    
    qoi=Mns2_s[:,i,:]#-Mts[i]
    colorv='k'
    zo=10
    yval=np.nanmedian(qoi,axis=1)
    lower_error=np.nanquantile(qoi,axis=1,q=0.25)
    upper_error=np.nanquantile(qoi,axis=1,q=0.75)
    asymmetric_error = [yval-lower_error, upper_error-yval]
    ax[1][i+2].errorbar(xoi, yval, yerr=asymmetric_error,c=colorv,marker='',ls='',alpha=0.5,lw=lw,zorder=zo)#, fmt='o')
    yval=np.nanmean(qoi,axis=1)
    ax[1][i+2].plot(xoi, yval,c=colorv,marker='o',fillstyle='none',ls='--',alpha=0.75,ms=ms,lw=lw,label=r'Naive',zorder=zo*100,markeredgewidth=mew)#, fmt='o')

    qoi=Mk0s2_s[:,i,:]#-Mts[i]
    colorv='g'
    zo=10
    yval=np.nanmedian(qoi,axis=1)
    lower_error=np.nanquantile(qoi,axis=1,q=0.25)
    upper_error=np.nanquantile(qoi,axis=1,q=0.75)
    asymmetric_error = [yval-lower_error, upper_error-yval]
    ax[1][i+2].errorbar(xoi, yval, yerr=asymmetric_error,c=colorv,marker='',ls='',alpha=0.5,lw=lw,zorder=zo)#, fmt='o')
    yval=np.nanmean(qoi,axis=1)
    ax[1][i+2].plot(xoi, yval,c=colorv,marker='>',fillstyle='none',ls='--',alpha=0.75,ms=ms,lw=lw,label=r'KV row',zorder=zo*100,markeredgewidth=mew)#, fmt='o')

    qoi=Mk1s2_s[:,i,:]#-Mts[i]
    colorv='g'
    zo=10
    yval=np.nanmedian(qoi,axis=1)
    lower_error=np.nanquantile(qoi,axis=1,q=0.25)
    upper_error=np.nanquantile(qoi,axis=1,q=0.75)
    asymmetric_error = [yval-lower_error, upper_error-yval]
    ax[1][i+2].errorbar(xoi, yval, yerr=asymmetric_error,c=colorv,marker='',ls='',alpha=0.5,lw=lw,zorder=zo)#, fmt='o')
    yval=np.nanmean(qoi,axis=1)
    ax[1][i+2].plot(xoi, yval,c=colorv,marker='<',fillstyle='none',ls='--',alpha=0.75,ms=ms,lw=lw,label=r'KV col',zorder=zo*100,markeredgewidth=mew)#, fmt='o')
  
    
    ax[1][i+2].hlines(Mts[i],np.min(Ps),np.max(Ps),color=cGT,alpha=alphaGT,lw=lwgt,label='GT')
    ax[1][i+2].set_xscale('log')
    ax[1][i+2].set_yscale('log')
    ax[1][i+2].set_xlabel('P')
    ax[1][i+2].set_title(r'$\hat{{m}}({})$'.format(i+2))

#plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

from matplotlib.ticker import MaxNLocator
ax[0][0].xaxis.set_major_locator(MaxNLocator(integer=True))
ax[0][1].xaxis.set_major_locator(MaxNLocator(integer=True))
ax[1][0].xaxis.set_major_locator(MaxNLocator(integer=True))
ax[1][1].xaxis.set_major_locator(MaxNLocator(integer=True))


fig.set_size_inches(w=6.75133, h=3)

fig.tight_layout()


#ax[0][0].legend()#fontsize=10)


#ax[0][0].text(-0.2, 1, "", ha="left", va="top", transform=ax[0][0].transAxes)

bbox = ax[0][0].get_tightbbox(fig.canvas.get_renderer())
fig.text(bbox.x0, bbox.y1, 'a.', fontsize=15, fontweight="bold", va="top", ha="left",
             transform=None)
    
bbox = ax[1][0].get_tightbbox(fig.canvas.get_renderer())
fig.text(bbox.x0, bbox.y1, 'b.', fontsize=15, fontweight="bold", va="top", ha="left",
             transform=None)


bbox = ax[0][2].get_tightbbox(fig.canvas.get_renderer())
fig.text(bbox.x0, bbox.y1, 'c.', fontsize=15, fontweight="bold", va="top", ha="left",
             transform=None)
    
bbox = ax[1][2].get_tightbbox(fig.canvas.get_renderer())
fig.text(bbox.x0, bbox.y1, 'd.', fontsize=15, fontweight="bold", va="top", ha="left",
             transform=None)

#plt.subplots_adjust(left = 0.1, top = 0.9, right = 0.9, bottom = 0.1, hspace = 1, wspace = 0.5)

eta=np.square(sigmax/sigma)
opnorm=np.power((-1+np.sqrt(1+4*eta))/(2*eta),d)
#ax[1][0].plot([2,kmax],opnorm *np.ones(2),'k-',alpha=0.4,lw=lw)


ax[1][0].annotate('', xy=(7, opnorm), xytext=(8, opnorm),
            arrowprops=dict(arrowstyle="->", color='k'))


plt.savefig('RBF.pgf', bbox_inches='tight')
# Out:
# /tmp/ipykernel_2754123/292337780.py:141: RuntimeWarning: invalid value encountered in power
#   Mss_p=np.power(Mss,1/np.arange(2,kmax+1)[:,None])

# %%
plt.savefig('RBF.pdf', bbox_inches='tight')

# %%
eta
# Out:
# 4.0
